# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dat = pd.read_excel('Importancevssatisfaction.xlsx')

# %%
dat
# Out:
#                      Importance  Satisfaction
# Fit                          10             9
# Fabric Feel                  10            10
# Color                         2             9
# Ontrend Design                5             5
# Graphics                      2             2
# Functionality                 4             8
# Price/ Value                  9             7
# Availablity                   8             8
# Durablity                     6             9
# Innovation                    8             4
# Packaging                     4            10
# Range of products             2             4
# Width of collection           2             3

# %%
color = np.random.random(13)
sns.scatterplot(x = dat['Importance'], y = dat['Satisfaction'], hue=dat.index)

# %%
fig, ax = plt.subplots(figsize = (15,8))
sns.scatterplot(x = dat['Importance'], y = dat['Satisfaction'], hue=dat.index, ax=ax)
ax.legend(loc='best', bbox_to_anchor=(1, 0.5), ncol=1)

# %%
fig.savefig('im.jpg')

# %%
box = ax.get_position()

# %%
box
# Out:
# Bbox([[0.125, 0.125], [0.9, 0.88]])

# %%
box.x0
# Out:
# 0.125

# %%
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
