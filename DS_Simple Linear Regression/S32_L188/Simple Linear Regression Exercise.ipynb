# %% [markdown]
# # Simple linear regression - exercise

# %% [markdown]
# You are given a real estate dataset.
#
# Real estate is one of those examples that every regression course goes through as it is extremely easy to understand and there is a (almost always) certain causal relationship to be found.
#
# The data is located in the file: 'real_estate_price_size.csv'.
#
# You are expected to create a simple linear regression (similar to the one in the lecture), using the new data.
#
# In this exercise, the dependent variable is 'price', while the independent variables is 'size'.
#
# Good luck!

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('real_estate_price_size.csv')

# %%
data.head(10)
# Out:
#         price     size
# 0  234314.144   643.09
# 1  228581.528   656.22
# 2  281626.336   487.29
# 3  401255.608  1504.75
# 4  458674.256  1275.46
# 5  245050.280   575.19
# 6  265129.064   570.89
# 7  175716.480   620.82
# 8  331101.344   682.26
# 9  218630.608   694.52

# %%
data.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
y = data['price']
x1 = data['size']

# %% [markdown]
# ### Explore the data

# %%
plt.scatter(x1,y)
plt.xlabel("Size", fontsize=20)
plt.ylabel("Price", fontsize=20)
plt.show()

# %% [markdown]
# ### Regression itself

# %%
#add constant
x = sm.add_constant(x1)

# %%
results = sm.OLS(y,x).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Thu, 12 Sep 2019   Prob (F-statistic):           8.13e-31
# Time:                        17:27:09   Log-Likelihood:                -1198.3
# No. Observations:                 100   AIC:                             2401.
# Df Residuals:                      98   BIC:                             2406.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.019e+05   1.19e+04      8.550      0.000    7.83e+04    1.26e+05
# size         223.1787     13.199     16.909      0.000     196.986     249.371
# ==============================================================================
# Omnibus:                        6.262   Durbin-Watson:                   2.267
# Prob(Omnibus):                  0.044   Jarque-Bera (JB):                2.938
# Skew:                           0.117   Prob(JB):                        0.230
# Kurtosis:                       2.194   Cond. No.                     2.75e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# >b0 = 1.019e+05
#
# >b1 = 223.1787

# %% [markdown]
# ### Plot the regression line on the initial scatter

# %%
plt.scatter(x1,y)
yhat = 1.019e+05 + 223.1787*x1
fig = plt.plot(x1, yhat, lw=4, c='orange', label='Regresssion Line')
plt.xlabel("Size", fontsize=15)
plt.ylabel("Price", fontsize=15)
plt.show()

# %%
d = pd.read_excel('4.10.Hypothesis-testing-section-practical-example-exercise.xlsx')

# %%
d.index
# Out:
# Float64Index([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#               ...
#               nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#              dtype='float64', length=177)

# %%
d.head()
# Out:
#     Practical example. Hypothesis testing. Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# NaN            Spark Fortress Inc. HR data        NaN        NaN        NaN
# NaN                                    NaN        NaN        NaN        NaN
# NaN                                Surname       Name        Age     Gender
# NaN                             Sweetwater       Alex         51       Male
# NaN                               Carabbio     Judith         30     Female
#
#         Unnamed: 4 Unnamed: 5           Unnamed: 6                 Unnamed: 7  \
# NaN            NaN        NaN                  NaN                        NaN
# NaN            NaN        NaN                  NaN                        NaN
# NaN        Country  Ethnicity           Start_date                 Department
# NaN  United States      White  2011-08-15 00:00:00  Software Engineering
# NaN  United States      White  2013-11-11 00:00:00       Software Engineering
#
#                        Unnamed: 8 Unnamed: 9  Unnamed: 10
# NaN                           NaN        NaN          NaN
# NaN                           NaN        NaN          NaN
# NaN                      Position     Salary          NaN
# NaN  Software Engineering Manager      56160          1.0
# NaN             Software Engineer     116480          1.0

# %%
d = d.reset_index()

# %%
d = d.drop(['index'], axis=1)

# %%
d = d.drop([0,1])

# %%
d = d.reset_index()

# %%
d = d.drop(['index'], axis=1)

# %%
d
# Out:
#     Practical example. Hypothesis testing.   Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                  Surname         Name        Age     Gender
# 1                               Sweetwater         Alex         51       Male
# 2                                 Carabbio       Judith         30     Female
# 3                                    Saada        Adell         31     Female
# 4                                    Szabo       Andrew         34       Male
# 5                                 Andreola        Colby         38     Female
# 6                                 Daneault         Lynn         27     Female
# 7                                 Houlihan        Debra         51     Female
# 8                                    Onque      Jasmine         27     Female
# 9                                   Jeremy        Peter         43       Male
# 10                                Gonzales      Ricardo         63       Male
# 11                                    Buck       Edward         42       Male
# 12                                  Carter     Michelle         54     Female
# 13                                   Costa        Latia         29     Female
# 14                                Dietrich        Jenna         30     Female
# 15                                  Givens       Myriam         28     Female
# 16                                Khemmich  Bartholemew         38       Male
# 17                                   Ozark       Travis         35       Male
# 18                                 Riordan      Michael         50       Male
# 19                                   Sahoo         Adil         31       Male
# 20                                  Blount       Dianna         27     Female
# 21                                Monkfish     Erasumus         25       Male
# 22                                  Nowlan      Kristie         32     Female
# 23                                 Burkett     Benjamin         40       Male
# 24                                McCarthy       Brigit         30     Female
# 25                                Johnston          Yen         48     Female
# 26                                 Woodson        Jason         32       Male
# 27                                  Erilus       Angela         28     Female
# 28                                 Hankard      Earnest         29       Male
# 29                                Buccheri       Joseph         34       Male
# ..                                     ...          ...        ...        ...
# 145                                DiNocco         Lily         39     Female
# 146                                   Owad      Clinton         38       Male
# 147                                 Sander       Kamrin         29     Female
# 148                                  Carey      Michael         34       Male
# 149                                 Gentry      Mildred         27     Female
# 150                                   Pitt         Brad         36       Male
# 151                               Gonzalez         Cayo         48       Male
# 152                                  Knapp    Bradley J         40       Male
# 153                               Sullivan        Kissy         39     Female
# 154                               Bramante        Elisa         34     Female
# 155                                   Soto        Julia         44     Female
# 156                                   Foss        Jason         37       Male
# 157                                 Murray       Thomas         29       Male
# 158                                  Brown          Mia         32     Female
# 159                              LaRotonda      William         33       Male
# 160                                 Martin       Sandra         30     Female
# 161                             Villanueva         Noah         28       Male
# 162                              Petingill        Shana         38     Female
# 163                                  Biden      Lowan M         59     Female
# 164                                 Rivera        Haley         45     Female
# 165                                 Stoica         Rick         32       Male
# 166                                Harrell      Ludwick         35       Male
# 167                             Kretschmer         John         37       Male
# 168                                Garneau       Hamish         37       Male
# 169                                 Ngodup        Shari         50     Female
# 170                                   Zima      Colleen         39     Female
# 171                                Sutwell      Barbara         49     Female
# 172                               Warfield        Sarah         39     Female
# 173                              Petrowsky       Thelma         33     Female
# 174                               Boutwell      Bonalyn         30     Female
#
# 3         Software Engineering             Software Engineer     102440
# 4         Software Engineering             Software Engineer      99840
# 5         Software Engineering             Software Engineer      99008
# 6                        Sales                 Sales Manager     112320
# 7                        Sales             Director of Sales     124800
# 8                        Sales            Area Sales Manager     118560
# 9                        Sales            Area Sales Manager     116480
# 10                       Sales            Area Sales Manager     115440
# 11                       Sales            Area Sales Manager     114400
# 12                       Sales            Area Sales Manager     114400
# 13                       Sales            Area Sales Manager     114400
# 14                       Sales            Area Sales Manager     114400
# 15                       Sales            Area Sales Manager     114400
# 16                       Sales            Area Sales Manager     114400
# 17                       Sales            Area Sales Manager     114400
# 18                       Sales            Area Sales Manager     114400
# 19           Production             Production Technician II      60320
# 20           Production             Production Technician II      56160
# 21           Production             Production Technician II      56160
# 22           Production             Production Technician II    54891.2
# 23           Production             Production Technician II      54080
# 24           Production             Production Technician II      54080
# 25           Production             Production Technician II      52000
# 26           Production             Production Technician II      50440
# 27           Production             Production Technician II      49920
# 28           Production             Production Technician II      49920
# 29           Production             Production Technician II      45760
# ..                         ...                           ...        ...
# 145          Production              Production Technician I      45760
# 146          Production              Production Technician I      45760
# 147          Production              Production Technician I      43680
# 148          Production              Production Technician I      41600
# 149          Production              Production Technician I      39520
# 150          Production              Production Technician I      35360
# 151          Production              Production Technician I      33280
# 152          Production              Production Technician I      29120
# 153          Production                   Production Manager     114400
# 154          Production               Director of Operations     124800
# 155                      IT/IS                    IT Support    57179.2
# 156                      IT/IS                   IT Director     135200
# 157                      IT/IS        Database Administrator      73840
# 158              Admin Offices                  Accountant I      59280
# 159              Admin Offices                  Accountant I      47840
# 160       Software Engineering             Software Engineer     115461
# 161                      Sales            Area Sales Manager     116480
# 162          Production             Production Technician II      54080
# 163          Production              Production Technician I      45760
# 164          Production              Production Technician I      45760
# 165          Production              Production Technician I      45760
# 166          Production              Production Technician I      43680
# 167          Production              Production Technician I      43680
# 168          Production              Production Technician I      37440
# 169          Production              Production Technician I      31200
# 170          Production              Production Technician I      31200
# 171          Production              Production Technician I      29120
# 172                      IT/IS          Sr. Network Engineer     114816
# 173                      IT/IS        Database Administrator      88920
# 174              Admin Offices                Sr. Accountant      72696
#
#      Unnamed: 10
# 0            NaN
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# 5            1.0
# 6            1.0
# 7            1.0
# 8            1.0
# 9            1.0
# 10           1.0
# 11           1.0
# 12           1.0
# 13           1.0
# 14           1.0
# 15           1.0
# 16           1.0
# 17           1.0
# 18           1.0
# 19           1.0
# 20           1.0
# 21           1.0
# 22           1.0
# 23           1.0
# 24           1.0
# 25           1.0
# 26           1.0
# 27           1.0
# 28           1.0
# 29           1.0
# ..           ...
# 145          0.0
# 146          0.0
# 147          0.0
# 148          0.0
# 149          0.0
# 150          0.0
# 151          0.0
# 152          0.0
# 153          0.0
# 154          0.0
# 155          0.0
# 156          0.0
# 157          0.0
# 158          0.0
# 159          0.0
# 160          0.0
# 161          0.0
# 162          0.0
# 163          0.0
# 164          0.0
# 165          0.0
# 166          0.0
# 167          0.0
# 168          0.0
# 169          0.0
# 170          0.0
# 171          0.0
# 172          0.0
# 173          0.0
# 174          0.0
#
# [175 rows x 11 columns]

# %%
d.
