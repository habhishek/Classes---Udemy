# %%
import pandas as pd
import numpy as np
import datetime as dt
from dateutil.relativedelta import relativedelta

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data'

# %%
data = pd.read_table(url, sep="\s+", engine='python', parse_dates=[[0,1,2]])
data
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# 5    2061-01-06  13.21   8.12   9.96   6.67   5.37   4.50  10.67   4.42
# 6    2061-01-07  13.50  14.29   9.50   4.96  12.29   8.33   9.17   9.29
# 7    2061-01-08  10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62
# 8    2061-01-09  12.58  10.83  10.00   4.75  10.37   6.79   8.04  10.13
# 9    2061-01-10  13.37  11.12  19.50   8.33   9.71   6.54  11.42   7.79
# 10   2061-01-11  10.58   9.87   8.42   2.79   8.71   7.25   7.54   8.33
# 11   2061-01-12  19.75  12.08  18.50  10.54  10.29   9.46  15.54  11.50
# ...

# %%
def fix_year(x):
    if x.year > 2000:
        x = x - relativedelta(years=100)
        return x
    else:
        return x

data.Yr_Mo_Dy = data.Yr_Mo_Dy.apply(fix_year)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=6574, step=1)

# %%
data.index = data.Yr_Mo_Dy

# %%
data.index
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Yr_Mo_Dy', length=6574, freq=None)

# %%
test = pd.DataFrame(np.arange(5), columns=['value'], index=['s1', 's2', 's3', 's4', 's5'])

# %%
test
# Out:
#     value
# s1      0
# s2      1
# s3      2
# s4      3
# s5      4

# %%
test.index
# Out:
# Index(['s1', 's2', 's3', 's4', 's5'], dtype='object')

# %%
def check(x):
    y = np.empty(len(x), dtype= bool)
    for i in range(len(x)):
        y[i] = x[i].endswith('1') or x[i].endswith('4')
    return y
        
mask = check(test.index.values)

# %%
def check(x):
    return x.endswith('1') or x.endswith('4')

# %%
test()
# Out:
# array([ True, False, False,  True, False])

# %%
test.iloc[mask]
# Out:
#     value
# s1      0
# s4      3
